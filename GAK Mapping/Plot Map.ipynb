# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Rectangle

# %%
#input

# top = -8.6
# bottom = -8.9
# left = 115
# right = 115.4

# lon = [115.21568817182758]
# lat = [-8.771705987198512]

# step = 0.05
# title = 'Tanjung Benoa Station'

# top = 20
# bottom = -20
# left = 90
# right = 150

# lon = [106.7, 106.85, 107.0]
# lat = [-5.87, -5.97]


# step = 0.1
# title = 'Jakarta Port'



#   108.5100   -7.7350
#   108.5100   -7.7150

#   108.5500   -7.7350
#   108.5500   -7.7150
#   108.5500   -7.6950
#   108.5900   -7.7350
#   108.5900   -7.7150
#   108.5900   -7.6950
#   108.6300   -7.7350
#   108.6300   -7.7150
#   108.6300   -7.6950

#   108.6450   -7.7050


# 106.70, -5.870
# 106.70, -5.970
# 106.85, -5.870
# 106.85, -5.970
# 107.00, -5.870
# 107.00, -5.970


# 106.7167   -5.9990
# 106.7167   -5.9375
# 106.7833   -5.9990
# 106.7833   -5.9375
# 106.8500   -5.9990
# 106.8500   -5.9375
# 106.9167   -5.9990
# 106.9167   -5.9375
# 106.9833   -5.9990
# 106.9833   -5.9375

# top = -5.85
# bottom = -6.1
# left = 106.6
# right = 107.1

# lon = [106.7167, 106.7833, 106.8500, 106.9167, 106.9833]
# lat = [-5.9990, -5.9375]

# step = 0.1
# title = 'Tanjung Priok'

# top = -5.85
# bottom = -6.1
# left = 106.6
# right = 107.1

# lon = [106.70, 106.85, 107.00]
# lat = [-5.870,-5.970]

# step = 0.1
# title = 'Wind Point Pangandaran'

# top = -7.62
# bottom = -8.2
# left = 108.3
# right = 108.9

# lon = [108.55, 108.59, 108.63]
# lat = [-7.7350,-7.7150, -7.6950]

# step = 0.1
# title = 'Pangandaran'


# 106.7167   -5.9990
# 106.7167   -5.9375
# 106.7833   -5.9990
# 106.7833   -5.9375
# 106.8500   -5.9990
# 106.8500   -5.9375
# 106.9167   -5.9990
# 106.9167   -5.9375
# 106.9833   -5.9990
# 106.9833   -5.9375


top = 4.2
bottom = 4
left = 96.1
right = 96.3

step = 2
title = 'Jakarta'

# %%
#Plot map
top = -1
bottom = -10
left = 100
right = 120

# lat = list(np.arange(-9,-8.5,0.25))
# lon = list(np.arange(114.25,116,0.25))

lon = [115.0899]
lat = [-8.3324]
# -8.332406330794138, 115.08990032182218
fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)
m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

# x,y = m(lon[0], lat[0])
# plt.annotate('BALI', xy=(x, y), xycoords='data', xytext=(-14, -20), textcoords='offset points', fontsize=16, fontweight='bold')

# x,y = m(96.2, 4.12)
# plt.annotate('Meulaboh', xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


# i = 1
# for lons in lon :
#   for lats in lat :
#     x,y = m(lons, lats)
#     m.plot(x, y, 'rv', markersize=12)
# #     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
#     i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,step),labels=[1,0,0,0], rotation=90, linewidth=0.25, fontsize=14)
m.drawmeridians(np.arange(-180,180,step),labels=[0,0,0,1], linewidth=0.25, fontsize=14)


spacingx = list(range(0, int((ax.get_xlim()[1])+6000), 6000))
spacingy = list(range(0, int((ax.get_ylim()[1])+6000), 6000))

for k in range(len(spacingx)):
    color='black' if k%2 == 0 else 'white'
    rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 6000,  2000, linewidth=1, edgecolor='k', facecolor=color)
    ax.add_patch(rect)

    rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-2000), 6000,  2000, linewidth=1, edgecolor='k', facecolor=color)
    ax.add_patch(rect)

    for j in range(len(spacingy)):
        color='black' if j%2 == 0 else 'white'
        rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 2000,  6000, linewidth=1, edgecolor='k', facecolor=color)
        ax.add_patch(rect)

        rect = Rectangle((ax.get_xlim()[1]-2000, ax.get_ylim()[0]+spacingy[j]), 2000,  6000, linewidth=1, edgecolor='k', facecolor=color)
        ax.add_patch(rect)

plt.xlabel('Longitude', labelpad=30, fontsize=18)
plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
# plt.savefig('Map_Jetty.png', dpi=100, bbox_inches = 'tight', pad_inches = 0)
# Out:
# Text(0, 0.5, 'Latitude')

# %%
#Plot map
top = -7.9
bottom = -9
left = 114.25
right = 115.9

# lat = list(np.arange(-9,-8.5,0.25))
# lon = list(np.arange(114.25,116,0.25))

lon = [115.0899]
lat = [-8.3324]
# -8.332406330794138, 115.08990032182218
fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)
m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('BALI', xy=(x, y), xycoords='data', xytext=(-14, -20), textcoords='offset points', fontsize=16, fontweight='bold')

# x,y = m(96.2, 4.12)
# plt.annotate('Meulaboh', xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


# i = 1
# for lons in lon :
#   for lats in lat :
#     x,y = m(lons, lats)
#     m.plot(x, y, 'rv', markersize=12)
# #     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
#     i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,step),labels=[1,0,0,0], rotation=90, linewidth=0.25, fontsize=14)
m.drawmeridians(np.arange(-180,180,step),labels=[0,0,0,1], linewidth=0.25, fontsize=14)


spacingx = list(range(0, int((ax.get_xlim()[1])+6000), 6000))
spacingy = list(range(0, int((ax.get_ylim()[1])+6000), 6000))

for k in range(len(spacingx)):
    color='black' if k%2 == 0 else 'white'
    rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 6000,  2000, linewidth=1, edgecolor='k', facecolor=color)
    ax.add_patch(rect)

    rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-2000), 6000,  2000, linewidth=1, edgecolor='k', facecolor=color)
    ax.add_patch(rect)

    for j in range(len(spacingy)):
        color='black' if j%2 == 0 else 'white'
        rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 2000,  6000, linewidth=1, edgecolor='k', facecolor=color)
        ax.add_patch(rect)

        rect = Rectangle((ax.get_xlim()[1]-2000, ax.get_ylim()[0]+spacingy[j]), 2000,  6000, linewidth=1, edgecolor='k', facecolor=color)
        ax.add_patch(rect)

plt.xlabel('Longitude', labelpad=30, fontsize=18)
plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_Jetty.png', dpi=100, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

top = 4.2
bottom = 4
left = 96.1
right = 96.232

lon = [96.1831]
lat = [4.1019]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)
m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('Jetty', xy=(x, y), xycoords='data', xytext=(-14, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)


# spacingx = list(range(0, int((ax.get_xlim()[1])+3000), 3000))
# spacingy = list(range(0, int((ax.get_ylim()[1])+3000), 3000))

# for k in range(len(spacingx)):
#     color='black' if k%2 == 0 else 'white'
#     rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-200), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     for j in range(len(spacingy)):
#         color='black' if j%2 == 0 else 'white'
#         rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

#         rect = Rectangle((ax.get_xlim()[1]-200, ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_Jetty.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

lon = [96.1680]
lat = [4.1014]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('F1', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')


m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)

# spacingx = list(range(0, int((ax.get_xlim()[1])+3000), 3000))
# spacingy = list(range(0, int((ax.get_ylim()[1])+3000), 3000))

# for k in range(len(spacingx)):
#     color='black' if k%2 == 0 else 'white'
#     rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-200), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     for j in range(len(spacingy)):
#         color='black' if j%2 == 0 else 'white'
#         rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

#         rect = Rectangle((ax.get_xlim()[1]-200, ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)
        
        
# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_F1.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

lon = [96.1767]
lat = [4.0948]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('F2', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')

m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_F2.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map


top = 4.2
bottom = 4
left = 96.1
right = 96.232

lon = [96.1849]
lat = [4.0884]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('F3', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')

m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_F3.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

lon = [96.1640]
lat = [4.0837]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('OF', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')


m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_OF.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

lon = [96.1802]
lat = [4.0997]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

x,y = m(lon[0], lat[0])
plt.annotate('ADCP', xy=(x, y), xycoords='data', xytext=(-20, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=12)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)
        
# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_ADCP.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map

lon = [96.1802]
lat = [4.0997]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

# x,y = m(lon[0], lat[0])
# plt.annotate('ADCP', xy=(x, y), xycoords='data', xytext=(-20, -20), textcoords='offset points', fontsize=16, fontweight='bold')

x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


# i = 1
# for lons in lon :
#   for lats in lat :
#     x,y = m(lons, lats)
#     m.plot(x, y, 'rv', markersize=12)
# #     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
#     i += 1


m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)
        
# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_Dom3.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)

# %%
#Plot map
top = 6
bottom = -6
left = 94
right = 101.9

step = 4
title = 'Jakarta'

lon = [96.1640]
lat = [4.0837]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)

m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

# x,y = m(lon[0], lat[0])
# plt.annotate('OF', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=16, fontweight='bold')

# x,y = m(96.2, 4.12)
# plt.annotate('Meulaboh', xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')


# i = 1
# for lons in lon :
#   for lats in lat :
#     x,y = m(lons, lats)
#     m.plot(x, y, 'rv', markersize=12)
# #     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
#     i += 1

# ax.patch.set_facecolor('#55d3f2')
m.drawmapboundary(fill_color='#55d3f2')
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')

print(ax.get_xlim()[1])

m.drawparallels(np.arange(-90,90,2),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,2.5),labels=[0,0,0,1], linewidth=0.5, fontsize=14)

# spacingx = list(range(0, int((ax.get_xlim()[1])+50000), 50000))
# spacingy = list(range(0, int((ax.get_ylim()[1])+50000), 50000))

# for k in range(len(spacingx)):
#     color='black' if k%2 == 0 else 'white'
#     rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 50000,  15000, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-15000), 50000,  15000, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     for j in range(len(spacingy)):
#         color='black' if j%2 == 0 else 'white'
#         rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 15000,  50000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

#         rect = Rectangle((ax.get_xlim()[1]-15000, ax.get_ylim()[0]+spacingy[j]), 15000,  50000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_Dom2.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)
# Out:
# 878439.506848982

# %%
#Plot map

top = 4.2
bottom = 4
left = 96.1
right = 96.232

lon = [96.1831]
lat = [4.1019]

fig = plt.figure(figsize=(10, 10))
ax = plt.subplot(111)
m = Basemap(projection='mill', resolution="f", 
            lat_0=sum(lat) / len(lat), lon_0=sum(lon) / len(lon),
           llcrnrlon = left,llcrnrlat = bottom,urcrnrlon = right,urcrnrlat = top)

lon = [96.1831]
lat = [4.1019]

x,y = m(lon[0], lat[0])
plt.annotate('Jetty', color='blue', xy=(x, y), xycoords='data', xytext=(-14, 10), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'bv', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    
lon = [96.1802]
lat = [4.0997]

x,y = m(lon[0], lat[0])
plt.annotate('ADCP', color='yellow', xy=(x, y), xycoords='data', xytext=(5, -15), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'v', color='yellow', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    
lon = [96.1640]
lat = [4.0837]

x,y = m(lon[0], lat[0])
plt.annotate('OF', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    
lon = [96.1849]
lat = [4.0884]

x,y = m(lon[0], lat[0])
plt.annotate('F3', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    
lon = [96.1767]
lat = [4.0948]

x,y = m(lon[0], lat[0])
plt.annotate('F2', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1
    
lon = [96.1680]
lat = [4.1014]

x,y = m(lon[0], lat[0])
plt.annotate('F1', xy=(x, y), xycoords='data', xytext=(-10, -20), textcoords='offset points', fontsize=12, fontweight='bold')

i = 1
for lons in lon :
  for lats in lat :
    x,y = m(lons, lats)
    m.plot(x, y, 'rv', markersize=8)
#     plt.annotate('P'+str(i), xy=(x, y), xycoords='data', xytext=(-8, 8), textcoords='offset points', fontsize=16)
    i += 1




x,y = m(96.18, 4.12)
plt.annotate('Meulaboh', rotation=-45, xy=(x, y), xycoords='data', xytext=(0,0), textcoords='offset points', fontsize=16, fontweight='bold')



m.drawmapboundary(fill_color='#55d3f2',zorder=0)
m.drawcoastlines(color='black')
m.fillcontinents(color='#5bf540')



m.drawparallels(np.arange(-90,90,0.03),labels=[1,0,0,0], rotation=90, linewidth=0.5, fontsize=14)
m.drawmeridians(np.arange(-180,180,0.03),labels=[0,0,0,1], linewidth=0.5, fontsize=14)


# spacingx = list(range(0, int((ax.get_xlim()[1])+3000), 3000))
# spacingy = list(range(0, int((ax.get_ylim()[1])+3000), 3000))

# for k in range(len(spacingx)):
#     color='black' if k%2 == 0 else 'white'
#     rect = Rectangle((ax.get_xlim()[0]+spacingx[k], ax.get_ylim()[0]), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     rect = Rectangle((ax.get_xlim()[1]-spacingx[k], ax.get_ylim()[1]-200), 6000,  200, linewidth=1, edgecolor='k', facecolor=color)
#     ax.add_patch(rect)

#     for j in range(len(spacingy)):
#         color='black' if j%2 == 0 else 'white'
#         rect = Rectangle((ax.get_xlim()[0], ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

#         rect = Rectangle((ax.get_xlim()[1]-200, ax.get_ylim()[0]+spacingy[j]), 200,  6000, linewidth=1, edgecolor='k', facecolor=color)
#         ax.add_patch(rect)

# plt.xlabel('Longitude', labelpad=30, fontsize=18)
# plt.ylabel('Latitude', labelpad=30, fontsize=18)
# plt.title(title, fontsize=24, pad=10, fontweight='bold')
# plt.legend(['Wave','Wind'])
plt.savefig('Map_All.png', dpi=87, bbox_inches = 'tight', pad_inches = 0)
